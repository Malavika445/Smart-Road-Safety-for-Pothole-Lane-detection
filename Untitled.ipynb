# %%
from ultralytics import YOLO
from ultralytics.yolo.v8.detect.predict import DetectionPredictor
from easygui import *
import cv2
import numpy as np
from lane import *
import pygame

pygame.mixer.init()
pygame.mixer.music.load("beep-125033.mp3")
#print(results)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
imgpoints, objpoints = collect_callibration_points()
model = YOLO("best.pt")
def detect_lane(file_type):
    
    if file_type=="image":
        path= fileopenbox("select the file")
        frame=cv2.imread(path)
        img=process_image(frame,imgpoints, objpoints)
        cv2.imshow("result", img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            #cap.release()
            cv2.destroyAllWindows()
            return
    elif file_type=="vedio":
        path= fileopenbox("select the file")
        cap = cv2.VideoCapture(path)
        while(cap.isOpened()):
             s, frame = cap.read()
             try:
                 img=process_image(frame,imgpoints, objpoints)
                 cv2.imshow("result", img)
                 if cv2.waitKey(1) & 0xFF == ord('q'):
                     break
             except:
                 cv2.imshow("result",frame)
                 if cv2.waitKey(1) & 0xFF == ord('q'):
                     break
             
        cap.release()
        cv2.destroyAllWindows()
        return
    else:
        cap = cv2.VideoCapture(0)
            
        while(cap.isOpened()):
             s, frame = cap.read()
             try:
                 img=process_image(frame,imgpoints, objpoints)
                 cv2.imshow("result", img)
                 if cv2.waitKey(1) & 0xFF == ord('q'):
                     break
             except:
                 cv2.imshow("result",frame)
                 if cv2.waitKey(1) & 0xFF == ord('q'):
                     break
        cap.release()
        cv2.destroyAllWindows()
        return
           
def detect_pathholes(file_type):
    
    if file_type=="image":
        path= fileopenbox("select the file")
        frame=cv2.imread(path)
        results = model.predict(source=frame, show=True)
        #cv2.imshow("result", img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            #cap.release()
            cv2.destroyAllWindows()
            return
    elif file_type=="vedio":
        path= fileopenbox("select the file")
        cap = cv2.VideoCapture(path)
        while(cap.isOpened()):
             s, frame = cap.read()
             results = model.predict(source=frame, show=True)
             try:
                if not results[0].boxes.shape[0]==0:
                    pygame.mixer.music.play()
             except:
                pass
             #cv2.imshow("result", img)
             if cv2.waitKey(1) & 0xFF == ord('q'):
                 break
        cap.release()
        cv2.destroyAllWindows()
        return
    else:
        cap = cv2.VideoCapture(0)
            
        while(cap.isOpened()):
             s, frame = cap.read()
             results = model.predict(source=frame, show=True)
             try:
                if not results[0].boxes.shape[0]==0:
                    pygame.mixer.music.play()
             except:
                pass
             #cv2.imshow("result", img)
             if cv2.waitKey(1) & 0xFF == ord('q'):
                 break
        cap.release()
        cv2.destroyAllWindows()
        return

   
    
def detect_both(file_type):
    if file_type=="image":
        path= fileopenbox("select the file")
        frame=cv2.imread(path)
        img=process_image(frame,imgpoints, objpoints)
        results = model.predict(source=img, show=True)
        #img=process_image(frame,imgpoints, objpoints)
        #cv2.imshow("result", img)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            #cap.release()
            cv2.destroyAllWindows()
            return
    elif file_type=="vedio":
        path= fileopenbox("select the file")
        cap = cv2.VideoCapture(path)
        #cap = cv2.VideoCapture(0)
        #start=False
    
        while(cap.isOpened()):
            s, frame = cap.read()
            #img = cv2.imread(imagePath)
            #gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            """
            if not s:
                continue
            if start==False:
                cv2.imshow("result", frame)
                if cv2.waitKey(1) & 0xFF == ord('S'):
                    start=True
                continue
            """ 
            #img=process_image(frame,imgpoints, objpoints)
            #results = model.predict(source=img, show=True)
            try:
                img=process_image(frame,imgpoints, objpoints)
                results = model.predict(source=img, show=True)
            except:
                results = model.predict(source=frame, show=True)
            try:
                if not results[0].boxes.shape[0]==0:
                    pygame.mixer.music.play()
            except:
                pass
            #print("type:",type(results))
            #cv2.imshow("result", img)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()
    else:
        #path= fileopenbox("select the file")
        #cap = cv2.VideoCapture(path)
        cap = cv2.VideoCapture(0)
        start=False
    
        while(cap.isOpened()):
            s, frame = cap.read()
            #img = cv2.imread(imagePath)
            #gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if not s:
                continue
            """
            if start==False:
                cv2.imshow("result", frame)
                if cv2.waitKey(1) & 0xFF == ord('S'):
                    start=True
                continue
            """
            try:
                img=process_image(frame,imgpoints, objpoints)
                results = model.predict(source=img, show=True)
            except:
                results = model.predict(source=frame, show=True)
            try:
                if not results[0].boxes.shape[0]==0:
                    pygame.mixer.music.play()
            except:
                pass
            #print("type:",type(results))
            #cv2.imshow("result", img)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()
# Out:
# C:\Users\neela\python\lib\site-packages\ultralytics\nn\tasks.py:332: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu')  # load

# %%
if __name__=="__main__":
    
        while True:
            text = "select one source "
                         # window title
            title = "lane and pathhole detection"
                         # item choices
            choices = ["image", "vedio", "cam","exit"]
             
            # creating a button box
            select = choicebox(text, title, choices)
            if select=="exit":
                break
            title1 = "select lane and pathhole "
             
            # item choices
            choices1 = ["lane", "pathholes", "lane_pathholes","exit"]
            
            text1="select the mode to detect"
            # creating a button box
            select1 = choicebox(text1, title1, choices1)
            if select1=="lane" and  select!="exit":
                #path= fileopenbox("select the file")
                try:
                    detect_lane(file_type=select)
                except:
                    print("it does not contain lanes and cam is not focusing on road")
            elif select1=="pathholes" and  select!="exit":
                #path= fileopenbox("select the  file")
                detect_pathholes(file_type=select)
                
            elif select1=="lane_pathholes" and  select!="exit":
                #path= fileopenbox("select the  file")
                try:
                    detect_both(file_type=select)
                except:
                    print("error there is no lane marks in the road")
            else :
                break
# Out:
# Ultralytics YOLOv8.0.21  Python-3.9.13 torch-2.5.1+cpu CPU
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# 0: 384x640 13 Potholess, 352.9ms
# Speed: 1.0ms pre-process, 352.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 333.9ms
# Speed: 2.7ms pre-process, 333.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 287.7ms
# Speed: 2.0ms pre-process, 287.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 16 Potholess, 283.0ms
# Speed: 1.0ms pre-process, 283.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 8 Potholess, 280.2ms
# Speed: 2.5ms pre-process, 280.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 291.7ms
# Speed: 1.0ms pre-process, 291.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 284.6ms
# Speed: 0.0ms pre-process, 284.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 13 Potholess, 316.1ms
# Speed: 1.0ms pre-process, 316.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 14 Potholess, 326.1ms
# Speed: 4.5ms pre-process, 326.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 13 Potholess, 293.3ms
# Speed: 0.0ms pre-process, 293.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 289.0ms
# Speed: 1.0ms pre-process, 289.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 15 Potholess, 317.9ms
# Speed: 0.0ms pre-process, 317.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 298.7ms
# Speed: 1.0ms pre-process, 298.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 278.5ms
# Speed: 1.0ms pre-process, 278.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 13 Potholess, 275.5ms
# Speed: 1.0ms pre-process, 275.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 278.8ms
# Speed: 1.0ms pre-process, 278.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 277.0ms
# Speed: 1.0ms pre-process, 277.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 14 Potholess, 279.0ms
# Speed: 1.0ms pre-process, 279.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 320.2ms
# Speed: 0.0ms pre-process, 320.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 309.4ms
# Speed: 1.0ms pre-process, 309.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 280.5ms
# Speed: 1.0ms pre-process, 280.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 13 Potholess, 284.8ms
# Speed: 1.0ms pre-process, 284.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 289.0ms
# Speed: 0.9ms pre-process, 289.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 284.8ms
# Speed: 1.0ms pre-process, 284.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 297.8ms
# Speed: 1.0ms pre-process, 297.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 295.2ms
# Speed: 1.5ms pre-process, 295.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 13 Potholess, 305.0ms
# Speed: 1.0ms pre-process, 305.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 8 Potholess, 294.6ms
# Speed: 1.0ms pre-process, 294.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 8 Potholess, 302.7ms
# Speed: 0.0ms pre-process, 302.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 9 Potholess, 294.7ms
# Speed: 1.0ms pre-process, 294.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 8 Potholess, 314.0ms
# Speed: 1.1ms pre-process, 314.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 308.9ms
# Speed: 1.0ms pre-process, 308.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 315.3ms
# Speed: 0.0ms pre-process, 315.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 9 Potholess, 307.8ms
# Speed: 1.0ms pre-process, 307.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 8 Potholess, 313.0ms
# Speed: 1.0ms pre-process, 313.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 311.8ms
# Speed: 1.0ms pre-process, 311.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 313.9ms
# Speed: 1.0ms pre-process, 313.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 9 Potholess, 311.7ms
# Speed: 1.0ms pre-process, 311.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 299.5ms
# Speed: 1.0ms pre-process, 299.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 299.2ms
# Speed: 0.0ms pre-process, 299.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 338.2ms
# Speed: 1.0ms pre-process, 338.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 9 Potholess, 327.6ms
# Speed: 1.4ms pre-process, 327.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 318.7ms
# Speed: 1.0ms pre-process, 318.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 312.2ms
# Speed: 1.5ms pre-process, 312.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 302.0ms
# Speed: 1.0ms pre-process, 302.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 307.7ms
# Speed: 0.0ms pre-process, 307.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 303.3ms
# Speed: 1.5ms pre-process, 303.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 315.0ms
# Speed: 0.0ms pre-process, 315.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 299.0ms
# Speed: 0.0ms pre-process, 299.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 302.0ms
# Speed: 1.0ms pre-process, 302.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 301.6ms
# Speed: 0.0ms pre-process, 301.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 302.5ms
# Speed: 0.0ms pre-process, 302.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 299.4ms
# Speed: 1.1ms pre-process, 299.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 296.3ms
# Speed: 0.0ms pre-process, 296.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 10 Potholess, 293.2ms
# Speed: 0.0ms pre-process, 293.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 11 Potholess, 295.8ms
# Speed: 1.5ms pre-process, 295.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 12 Potholess, 296.1ms
# Speed: 1.8ms pre-process, 296.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 384x640 13 Potholess, 301.2ms
# Speed: 1.0ms pre-process, 301.2ms inference, 56.7ms postprocess per image at shape (1, 3, 640, 640)
# it does not contain lanes and cam is not focusing on road

# %%
"""
if __name__=="__main__":
        model = YOLO("best.pt")
        imgpoints, objpoints = collect_callibration_points()
        cap = cv2.VideoCapture("demo_1.mp4")
        #cap = cv2.VideoCapture(0)
        start=False
    
        while(cap.isOpened()):
            
            s, frame = cap.read()
            #img = cv2.imread(imagePath)
            #gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if not s:
                continue
            if start==False:
                cv2.imshow("result", frame)
                if cv2.waitKey(1) & 0xFF == ord('S'):
                    start=True
                continue
            
            #img=process_image(frame,imgpoints, objpoints)
            results = model.predict(source=frame, show=True)
            try:
                if not results[0].boxes.shape[0]==0:
                    pygame.mixer.music.play()
            except:
                pass
            #print("type:",type(results))
            #cv2.imshow("result", img)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()

"""
